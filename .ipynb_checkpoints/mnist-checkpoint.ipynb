# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from keras_preprocessing import image
from tensorflow.keras.optimizers import Adam, Adadelta 
from tensorflow.keras import utils 
from tensorflow.keras.preprocessing import image 
import numpy as np
import matplotlib.pyplot as plt 
from PIL import Image
import random 
import math
import os
from sklearn.model_selection import train_test_split
import pandas as pd
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
y = df_train['label'].values
df_train = df_train.drop(columns = 'label')
x = df_train.values
x = x/255

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7 ,random_state = 42)
x_train = x_train.reshape((x_train.shape[0], 28, 28,1))
x_test = x_test.reshape((x_test.shape[0], 28, 28,1))

# %%
#one hot encoding
y_train = utils.to_categorical(y_train, 10)
y_test = utils.to_categorical(y_test, 10)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# %%
batch_size = 64 
epochs = 100

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), padding='same', input_shape=(28, 28, 1), activation='relu'))
model.add(Conv2D(32, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])


history = model.fit(x_train, 
                    y_train, 
                    batch_size=batch_size, 
                    epochs=epochs,
                    validation_data=(x_test, y_test),)

plt.plot(history.history['accuracy'], 
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'], 
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.3072 - accuracy: 0.9042 - val_loss: 0.8060 - val_accuracy: 0.7826
# Epoch 2/100
# 460/460 [==============================] - 135s 293ms/step - loss: 0.0881 - accuracy: 0.9730 - val_loss: 0.0709 - val_accuracy: 0.9785
# Epoch 3/100
# 460/460 [==============================] - 129s 281ms/step - loss: 0.0653 - accuracy: 0.9806 - val_loss: 0.0532 - val_accuracy: 0.9851
# Epoch 4/100
# 460/460 [==============================] - 128s 278ms/step - loss: 0.0540 - accuracy: 0.9834 - val_loss: 0.0474 - val_accuracy: 0.9859
# Epoch 5/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0445 - accuracy: 0.9869 - val_loss: 0.0693 - val_accuracy: 0.9812
# Epoch 6/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0405 - accuracy: 0.9878 - val_loss: 0.0370 - val_accuracy: 0.9908
# Epoch 7/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0365 - accuracy: 0.9895 - val_loss: 0.0405 - val_accuracy: 0.9902
# Epoch 8/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0339 - accuracy: 0.9894 - val_loss: 0.0448 - val_accuracy: 0.9876
# Epoch 9/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0353 - accuracy: 0.9901 - val_loss: 0.0441 - val_accuracy: 0.9882
# Epoch 10/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0301 - accuracy: 0.9906 - val_loss: 0.0784 - val_accuracy: 0.9788
# Epoch 11/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.0341 - val_accuracy: 0.9901
# Epoch 12/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0249 - accuracy: 0.9929 - val_loss: 0.0356 - val_accuracy: 0.9908
# Epoch 13/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.0396 - val_accuracy: 0.9902
# Epoch 14/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0272 - accuracy: 0.9922 - val_loss: 0.0350 - val_accuracy: 0.9910
# Epoch 15/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.0494 - val_accuracy: 0.9871
# Epoch 16/100
# 460/460 [==============================] - 122s 265ms/step - loss: 0.0214 - accuracy: 0.9936 - val_loss: 0.0308 - val_accuracy: 0.9919
# Epoch 17/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0177 - accuracy: 0.9948 - val_loss: 0.0410 - val_accuracy: 0.9894
# Epoch 18/100
# 460/460 [==============================] - 122s 265ms/step - loss: 0.0195 - accuracy: 0.9940 - val_loss: 0.0510 - val_accuracy: 0.9880
# Epoch 19/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0198 - accuracy: 0.9940 - val_loss: 0.0307 - val_accuracy: 0.9917
# Epoch 20/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0280 - val_accuracy: 0.9933
# Epoch 21/100
# 460/460 [==============================] - 124s 269ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0342 - val_accuracy: 0.9921
# Epoch 22/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0165 - accuracy: 0.9951 - val_loss: 0.0374 - val_accuracy: 0.9914
# Epoch 23/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0296 - val_accuracy: 0.9931
# Epoch 24/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.0301 - val_accuracy: 0.9924
# Epoch 25/100
# 460/460 [==============================] - 124s 270ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.0393 - val_accuracy: 0.9903
# Epoch 26/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0334 - val_accuracy: 0.9920
# Epoch 27/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 0.0325 - val_accuracy: 0.9929
# Epoch 28/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0289 - val_accuracy: 0.9931
# Epoch 29/100
# 460/460 [==============================] - 129s 281ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.0337 - val_accuracy: 0.9923
# Epoch 30/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.0325 - val_accuracy: 0.9925
# Epoch 31/100
# 460/460 [==============================] - 127s 276ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.0322 - val_accuracy: 0.9928
# Epoch 32/100
# 460/460 [==============================] - 122s 264ms/step - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.0281 - val_accuracy: 0.9937
# Epoch 33/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.0324 - val_accuracy: 0.9927
# Epoch 34/100
# 460/460 [==============================] - 123s 266ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0361 - val_accuracy: 0.9927
# Epoch 35/100
# 460/460 [==============================] - 124s 271ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0468 - val_accuracy: 0.9892
# Epoch 36/100
# 460/460 [==============================] - 131s 285ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.0312 - val_accuracy: 0.9940
# Epoch 37/100
# 460/460 [==============================] - 129s 280ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0324 - val_accuracy: 0.9944
# Epoch 38/100
# 460/460 [==============================] - 134s 291ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.0346 - val_accuracy: 0.9938
# Epoch 39/100
# 460/460 [==============================] - 127s 275ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0334 - val_accuracy: 0.9929
# Epoch 40/100
# 460/460 [==============================] - 147s 319ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0442 - val_accuracy: 0.9924
# Epoch 41/100
# 460/460 [==============================] - 138s 300ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0338 - val_accuracy: 0.9933
# Epoch 42/100
# 460/460 [==============================] - 131s 285ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0509 - val_accuracy: 0.9898
# Epoch 43/100
# 460/460 [==============================] - 132s 287ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0288 - val_accuracy: 0.9938
# Epoch 44/100
# 460/460 [==============================] - 138s 301ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0277 - val_accuracy: 0.9936
# Epoch 45/100
# 460/460 [==============================] - 132s 287ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0318 - val_accuracy: 0.9948
# Epoch 46/100
# 460/460 [==============================] - 125s 272ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.0324 - val_accuracy: 0.9928
# Epoch 47/100
# 460/460 [==============================] - 127s 276ms/step - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.0289 - val_accuracy: 0.9938
# Epoch 48/100
# 460/460 [==============================] - 124s 269ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0336 - val_accuracy: 0.9929
# Epoch 49/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0319 - val_accuracy: 0.9938
# Epoch 50/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0319 - val_accuracy: 0.9940
# Epoch 51/100
# 460/460 [==============================] - 124s 270ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0356 - val_accuracy: 0.9944
# Epoch 52/100
# 460/460 [==============================] - 124s 270ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0363 - val_accuracy: 0.9925
# Epoch 53/100
# 460/460 [==============================] - 135s 293ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0294 - val_accuracy: 0.9934
# Epoch 54/100
# 460/460 [==============================] - 126s 275ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0304 - val_accuracy: 0.9938
# Epoch 55/100
# 460/460 [==============================] - 122s 265ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0334 - val_accuracy: 0.9938
# Epoch 56/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0376 - val_accuracy: 0.9938
# Epoch 57/100
# 460/460 [==============================] - 125s 271ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0363 - val_accuracy: 0.9940
# Epoch 58/100
# 460/460 [==============================] - 126s 274ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0405 - val_accuracy: 0.9917
# Epoch 59/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.0297 - val_accuracy: 0.9939
# Epoch 60/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0320 - val_accuracy: 0.9934
# Epoch 61/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0318 - val_accuracy: 0.9936
# Epoch 62/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0314 - val_accuracy: 0.9941
# Epoch 63/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.0312 - val_accuracy: 0.9936
# Epoch 64/100
# 460/460 [==============================] - 136s 296ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0413 - val_accuracy: 0.9923
# Epoch 65/100
# 460/460 [==============================] - 126s 274ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0367 - val_accuracy: 0.9933
# Epoch 66/100
# 460/460 [==============================] - 126s 275ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0306 - val_accuracy: 0.9942
# Epoch 67/100
# 460/460 [==============================] - 126s 273ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0424 - val_accuracy: 0.9920
# Epoch 68/100
# 460/460 [==============================] - 127s 277ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.0433 - val_accuracy: 0.9910
# Epoch 69/100
# 460/460 [==============================] - 128s 277ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0368 - val_accuracy: 0.9928
# Epoch 70/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.0380 - val_accuracy: 0.9935
# Epoch 71/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.0344 - val_accuracy: 0.9943
# Epoch 72/100
# 460/460 [==============================] - 126s 275ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0311 - val_accuracy: 0.9935
# Epoch 73/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0336 - val_accuracy: 0.9931
# Epoch 74/100
# 460/460 [==============================] - 124s 269ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0337 - val_accuracy: 0.9940
# Epoch 75/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0362 - val_accuracy: 0.9928
# Epoch 76/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0370 - val_accuracy: 0.9936
# Epoch 77/100
# 460/460 [==============================] - 125s 271ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0387 - val_accuracy: 0.9934
# Epoch 78/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0401 - val_accuracy: 0.9937
# Epoch 79/100
# 460/460 [==============================] - 123s 266ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0336 - val_accuracy: 0.9932
# Epoch 80/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0391 - val_accuracy: 0.9929
# Epoch 81/100
# 460/460 [==============================] - 124s 269ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0335 - val_accuracy: 0.9944
# Epoch 82/100
# 460/460 [==============================] - 125s 271ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0401 - val_accuracy: 0.9936
# Epoch 83/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0348 - val_accuracy: 0.9946
# Epoch 84/100
# 460/460 [==============================] - 123s 266ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.0426 - val_accuracy: 0.9930
# Epoch 85/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0392 - val_accuracy: 0.9940
# Epoch 86/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0414 - val_accuracy: 0.9925
# Epoch 87/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0413 - val_accuracy: 0.9934
# Epoch 88/100
# 460/460 [==============================] - 127s 276ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0380 - val_accuracy: 0.9946
# Epoch 89/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0425 - val_accuracy: 0.9929
# Epoch 90/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0389 - val_accuracy: 0.9940
# Epoch 91/100
# 460/460 [==============================] - 126s 273ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0363 - val_accuracy: 0.9933
# Epoch 92/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0440 - val_accuracy: 0.9935
# Epoch 93/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0404 - val_accuracy: 0.9930
# Epoch 94/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0405 - val_accuracy: 0.9932
# Epoch 95/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0369 - val_accuracy: 0.9940
# Epoch 96/100
# 460/460 [==============================] - 123s 268ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0378 - val_accuracy: 0.9934
# Epoch 97/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0371 - val_accuracy: 0.9939
# Epoch 98/100
# 460/460 [==============================] - 123s 267ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0370 - val_accuracy: 0.9943
# Epoch 99/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0332 - val_accuracy: 0.9942
# Epoch 100/100
# 460/460 [==============================] - 122s 266ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0310 - val_accuracy: 0.9949

# %%
testik = df_test.values
testik = testik/255
testik = testik.reshape((testik.shape[0], 28, 28,1))
prediction = model.predict(testik)
predict = np.array(np.round(prediction), dtype = np.int32)
predict = np.argmax(predict , axis=1).reshape(-1, 1)

# %%
submission_df = pd.read_csv("sample_submission.csv")
submission_df['Label'] = predict
submission_df.to_csv('submission.csv', index=False)
